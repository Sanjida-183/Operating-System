# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjida-183/Operating-System/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque



class Process:

    def __init__(self, pid, at, bt):

        self.pid, self.at, self.bt, self.rt = pid, at, bt, bt

        self.ct = self.tat = self.wt = 0



n = int(input("Enter number of processes: "))

procs = [Process(f"p{i+1}", int(input(f"AT p{i+1}: ")), int(input(f"BT p{i+1}: "))) for i in range(n)]

procs.sort(key=lambda p: p.at)



tq, time, done = 5, 0, 0

q, visited = deque(), set()



def enqueue():

    for p in procs:

        if p.at <= time and p.pid not in visited and p.rt > 0:

            q.append(p)

            visited.add(p.pid)



enqueue()

while done < n:

    if not q:

        time += 1

        enqueue()

        continue



    curr = q.popleft()

    exec_time = min(tq, curr.rt)

    curr.rt -= exec_time

    time += exec_time



    enqueue()

    if curr.rt > 0:

        q.append(curr)

    else:

        curr.ct = time

        curr.tat = curr.ct - curr.at

        curr.wt = curr.tat - curr.bt

        done += 1



print("\nPID\tAT\tBT\tCT\tTAT\tWT")

for p in sorted(procs, key=lambda x: int(x.pid[1:])):

    print(f"{p.pid}\t{p.at}\t{p.bt}\t{p.ct}\t{p.tat}\t{p.wt}")



print(f"\nAvg TAT: {sum(p.tat for p in procs)/n:.2f}")

print(f"Avg WT:  {sum(p.wt for p in procs)/n:.2f}")
# Out:
# Enter number of processes: 6
# AT p1: 0
# BT p1: 7
# AT p2: 1
# BT p2: 4
# AT p3: 2
# BT p3: 15
# AT p4: 3
# BT p4: 11
# AT p5: 4
# BT p5: 20
# AT p6: 4
# BT p6: 9
#
# PID	AT	BT	CT	TAT	WT
# p1	0	7	31	31	24
# p2	1	4	9	8	4
# p3	2	15	55	53	38
# p4	3	11	56	53	42
# p5	4	20	66	62	42
# p6	4	9	50	46	37
#
# Avg TAT: 42.17
# Avg WT:  31.17
